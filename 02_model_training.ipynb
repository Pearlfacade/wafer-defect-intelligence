# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

dataset_path = "wm-811k-augmented-and-preprocessed-dataset/archive (4)/data"

classes = os.listdir(os.path.join(dataset_path,"train"))

# %%
print("Dataset size per class:\n")

for cls in classes:

    folder_path = os.path.join(dataset_path, "train", cls)

    count = len(os.listdir(folder_path))

    print(f"{cls}: {count} images")
# Out:
# Dataset size per class:
#
# Center: 500 images
# Donut: 500 images
# Edge-Loc: 500 images
# Edge-Ring: 500 images
# Loc: 500 images
# Near-full: 500 images
# none: 500 images
# Random: 500 images
# Scratch: 500 images

# %%
fig, axes = plt.subplots(len(classes), 3, figsize=(15, 20))

for row, defect in enumerate(classes):

    folder = os.path.join(dataset_path, "train", defect)

    all_images = os.listdir(folder)

    random_images = random.sample(all_images, min(3, len(all_images)))

    for col, image_name in enumerate(random_images):

        image_path = os.path.join(folder, image_name)

        img = mpimg.imread(image_path)

        axes[row, col].imshow(img)

        if col == 0:
            axes[row, col].set_ylabel(defect, fontsize=12)

        axes[row, col].axis("off")

plt.suptitle("Three Random Samples From Every Defect Class", fontsize=16)

plt.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 9
#       5 folder = os.path.join(dataset_path, "train", defect)
#       7 all_images = os.listdir(folder)
# ----> 9 random_images = random.sample(all_images, min(3, len(all_images)))
#      11 for col, image_name in enumerate(random_images):
#      13     image_path = os.path.join(folder, image_name)
#
# NameError: name 'random' is not defined

# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

print("Libraries loaded successfully!")
# Out:
# Libraries loaded successfully!

# %%
dataset_path = "wm-811k-augmented-and-preprocessed-dataset/archive (4)/data"

print("Dataset Path:")
print(dataset_path)
# Out:
# Dataset Path:
# wm-811k-augmented-and-preprocessed-dataset/archive (4)/data

# %%
classes = os.listdir(os.path.join(dataset_path, "train"))

print("Classes Found:\n")
print(classes)
# Out:
# Classes Found:
#
# ['Center', 'Donut', 'Edge-Loc', 'Edge-Ring', 'Loc', 'Near-full', 'none', 'Random', 'Scratch']

# %%
print("Dataset size per class:\n")

for cls in classes:

    folder_path = os.path.join(dataset_path, "train", cls)

    count = len(os.listdir(folder_path))

    print(f"{cls}: {count} images")
# Out:
# Dataset size per class:
#
# Center: 500 images
# Donut: 500 images
# Edge-Loc: 500 images
# Edge-Ring: 500 images
# Loc: 500 images
# Near-full: 500 images
# none: 500 images
# Random: 500 images
# Scratch: 500 images

# %%
fig, axes = plt.subplots(len(classes), 3, figsize=(15, 20))

for row, defect in enumerate(classes):

    folder = os.path.join(dataset_path, "train", defect)

    all_images = os.listdir(folder)

    random_images = random.sample(all_images, min(3, len(all_images)))

    for col, image_name in enumerate(random_images):

        image_path = os.path.join(folder, image_name)

        img = mpimg.imread(image_path)

        axes[row, col].imshow(img)

        if col == 0:
            axes[row, col].set_ylabel(defect, fontsize=12)

        axes[row, col].axis("off")

plt.suptitle("Three Random Samples From Every Defect Class", fontsize=16)

plt.tight_layout()

plt.show()

# %%
defect_mapping = {

    "Center": {},

    "Donut": {},

    "Edge-Loc": {},

    "Edge-Ring": {},

    "Loc": {},

    "Near-full": {},

    "none": {},

    "Random": {},

    "Scratch": {}
}

# %%
defect_mapping["Center"] = {

    "physical_cause":"",

    "process_step":"",

    "equipment":"",

    "how_to_fix":""
}

defect_mapping["Donut"] = {

    "physical_cause":"",

    "process_step":"",

    "equipment":"",

    "how_to_fix":""
}

defect_mapping["Edge-Loc"] = {

    "physical_cause":"",

    "process_step":"",

    "equipment":"",

    "how_to_fix":""
}

defect_mapping["Edge-Ring"] = {

    "physical_cause":"",

    "process_step":"",

    "equipment":"",

    "how_to_fix":""
}

defect_mapping["Loc"] = {

    "physical_cause":"",

    "process_step":"",

    "equipment":"",

    "how_to_fix":""
}

defect_mapping["Near-full"] = {

    "physical_cause":"",

    "process_step":"",

    "equipment":"",

    "how_to_fix":""
}

defect_mapping["none"] = {

    "physical_cause":"Normal statistical variation",

    "process_step":"All process steps",

    "equipment":"None",

    "how_to_fix":"No action needed"
}

defect_mapping["Random"] = {

    "physical_cause":"",

    "process_step":"",

    "equipment":"",

    "how_to_fix":""
}

defect_mapping["Scratch"] = {

    "physical_cause":"",

    "process_step":"",

    "equipment":"",

    "how_to_fix":""
}

# %%
for defect, info in defect_mapping.items():

    print("\n" + "="*40)

    print(defect.upper())

    print("="*40)

    for key, value in info.items():

        print(f"{key}: {value}")
# Out:
# ...
# CENTER
# ...
# physical_cause:
# process_step:
# equipment:
# how_to_fix:
#
# ...
# DONUT
# ...
# physical_cause:
# process_step:
# equipment:
# how_to_fix:
#
# ...
# EDGE-LOC
# ...
# physical_cause:
# process_step:
# equipment:
# how_to_fix:
#
# ...
# EDGE-RING
# ...
# physical_cause:
# process_step:
# equipment:
# how_to_fix:
#
# ...
# LOC
# ...
# physical_cause:
# process_step:
# equipment:
# how_to_fix:
#
# ...
# NEAR-FULL
# ...
# physical_cause:
# process_step:
# equipment:
# how_to_fix:
#
# ...
# NONE
# ...
# physical_cause: Normal statistical variation
# process_step: All process steps
# equipment: None
# how_to_fix: No action needed
#
# ...
# RANDOM
# ...
# physical_cause:
# process_step:
# equipment:
# how_to_fix:
#
# ...
# SCRATCH
# ...
# physical_cause:
# process_step:
# equipment:
# how_to_fix:

# %%
ANSWER=""" ======================================== CENTER ========================================
physical_cause: Uneven spin coating during resist application, or deposition nozzle centered too high
process_step: Photoresist coating (after cleaning) OR early deposition step
equipment: Applied Materials (deposition tool)
how_to_fix: Adjust spin speed profile, check nozzle height, tune gas flow distribution

======================================== DONUT ========================================
physical_cause: Edge exclusion ring + plasma confinement ring malfunction in etch tool
process_step: Etch step
equipment: Lam Research (etch tool)
how_to_fix: Inspect and recalibrate plasma confinement ring, verify edge exclusion parameters

======================================== EDGE-LOC ========================================
physical_cause: Physical contact from robot arm or wafer carrier burr, localized mechanical damage
process_step: Wafer handling/transport (between etch and next step)
equipment: Wafer transport system, robot arms
how_to_fix: Inspect robot end-effector for wear, check wafer carrier for burrs, replace if damaged

======================================== EDGE-RING ========================================
physical_cause: Systematic edge effect - plasma non-uniformity at edge of etch chamber, or resist thickness variation at edge
process_step: Etch step (or lithography if resist thickness issue)
equipment: Lam Research (etch tool) OR ASML (lithography if resist-related)
how_to_fix: Adjust plasma confinement parameters, verify edge exclusion, tune resist dispense profile

======================================== LOC ========================================
physical_cause: Localized mask defect on reticle, or particle contamination on photomask during lithography
process_step: Lithography (photoresist exposure)
equipment: ASML (lithography tool)
how_to_fix: Inspect reticle/mask for defects, clean mask, replace if contaminated, check for particles

======================================== NEAR-FULL ========================================
physical_cause: Major process excursion - wrong gas mix, wrong temperature, equipment failure, major contamination event
process_step: Critical step (could be etch, deposition, or lithography)
equipment: Any - requires investigation across multiple tools
how_to_fix: Check equipment error logs, verify gas flows and temperatures, run process control charts, may need to scrap entire lot

======================================== NONE ========================================
physical_cause: Normal statistical variation
process_step: All steps
equipment: None - wafer is acceptable
how_to_fix: No action needed

======================================== RANDOM ========================================
physical_cause: Process parameter drift affecting entire wafer uniformly - wrong temperature, wrong gas concentration, contamination in process chamber
process_step: Could be any step - deposition, etch, or lithography
equipment: Any equipment - SPC (Statistical Process Control) required to identify which
how_to_fix: Run SPC control charts to identify which parameter drifted, adjust process recipe, check chamber cleanliness

======================================== SCRATCH ========================================
physical_cause: Linear physical contact - CMP polishing pad defect, robot arm contact during handling, wafer carrier edge contact
process_step: CMP (polishing) OR wafer handling/transport
equipment: Applied Materials (CMP tool) OR wafer transport robots
how_to_fix: Inspect and replace CMP polishing pad, check robot arms for contamination/wear, inspect wafer carriers for burrs"""
