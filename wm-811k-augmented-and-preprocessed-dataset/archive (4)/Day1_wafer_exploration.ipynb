# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("All imports successful")
# Out:
# All imports successful

# %%
import os
print(os.listdir('.'))
# Out:
# ['.ipynb_checkpoints', 'data', 'Untitled.ipynb']

# %%
import os

print(os.listdir('data'))
# Out:
# ['test', 'train', 'validation']

# %%
import os

print(os.listdir('data/train'))
# Out:
# ['Center', 'Donut', 'Edge-Loc', 'Edge-Ring', 'Loc', 'Near-full', 'none', 'Random', 'Scratch']

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

print("Libraries loaded successfully!")
# Out:
# Libraries loaded successfully!

# %%
classes = os.listdir("data/train")
print(classes)
# Out:
# ['Center', 'Donut', 'Edge-Loc', 'Edge-Ring', 'Loc', 'Near-full', 'none', 'Random', 'Scratch']

# %%
fig, axes = plt.subplots(3, 3, figsize=(12,12))
axes = axes.flatten()

for i, defect in enumerate(classes):

    folder = os.path.join("data/train", defect)

    image_name = os.listdir(folder)[0]

    image_path = os.path.join(folder, image_name)

    img = mpimg.imread(image_path)

    axes[i].imshow(img)
    axes[i].set_title(defect)
    axes[i].axis("off")

plt.tight_layout()
plt.show()

# %%
observations="""
Centre: more amount of blue dots at the centre
Donut: small ring type formation at the centre 
Edge-loc: Some places at the edge has blue dots
Edge-ring: blue dots are around the ring
LOC: localllized, in few places but clusterly
Near-full- wafer is almost filled with blue dot
Scratch: whole wafer is ring slight blue lines are there which seems parallel
Random: randomized way the blue dots are there


centre & donut: is the only difference is blue dots are accumulated at centre and donut has it ring like?
how do we differentiate between random and LOC : almost same;
also how one with less number of blue dot is classified as NONE where as the scratch classified one has far lesser blue dot than NONE
THE NONE one suprised me the most.
in my opinion the placement mistake while putting waffer in and out caused the scratch
"""
print(observations)
# Out:
# Centre: more amount of blue dots at the centre
# Donut: small ring type formation at the centre
# Edge-loc: Some places at the edge has blue dots
# Edge-ring: blue dots are around the ring
# LOC: localllized, in few places but clusterly
# Near-full- wafer is almost filled with blue dot
# Scratch: whole wafer is ring slight blue lines are there which seems parallel
# Random: randomized way the blue dots are there
#
#
# centre & donut: is the only difference is blue dots are accumulated at centre and donut has it ring like?
# how do we differentiate between random and LOC : almost same;
# also how one with less number of blue dot is classified as NONE where as the scratch classified one has far lesser blue dot than NONE
# THE NONE one suprised me the most.
# in my opinion the placement mistake while putting waffer in and out caused the scratch
